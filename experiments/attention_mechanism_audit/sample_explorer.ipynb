# %% [markdown]
# # Inspect one saved QA response
#
# Change only SAMPLE_ID, then run both cells. This reads existing traces and does not replay the model.

# %%
from pathlib import Path

from experiments.attention_mechanism_audit.evaluate import plot_saved_sample

REPO = Path('/share/home/tm902089733300000/a903202310/lys/research/graph')
MODEL = Path('/share/home/tm902089733300000/a903202310/lys/models/Meta-Llama-3.1-8B-Instruct')
CACHE = Path('/share/home/tm902089733300000/a903202310/lys/research/Unsupervised-hypergraph/outputs/attention_cache/fresh_attention_c8847872bedf_20260731T074520Z_p876')
OUT = REPO / 'experiments/attention_mechanism_audit/outputs/qa/Meta-Llama-3.1-8B-Instruct_teacher_forced_seed20260828'
test_traces = OUT / 'traces' if (OUT / 'traces/index.jsonl').is_file() else OUT / 'test/traces'
INPUTS = [(OUT / 'train/traces', CACHE / 'train'), (test_traces, CACHE / 'test')]

SAMPLE_ID = '11907'
IMAGE = OUT / 'sample_views' / f'{SAMPLE_ID}.png'

# %%
from IPython.display import Image, display

plot_saved_sample(inputs=INPUTS, sample_id=SAMPLE_ID, model_path=MODEL, output=IMAGE)
display(Image(filename=str(IMAGE)))
