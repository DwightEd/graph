# %% [markdown]
# # Inspect one saved response
#
# Change only SAMPLE_ID, then run both cells. This reads existing mechanism states and does not replay the model.

# %%
from pathlib import Path

from experiments.attention_mechanism_audit.evaluate import plot_saved_sample

REPO = Path("/share/home/tm902089733300000/a903202310/lys/research/graph")
MODEL = Path(
    "/share/home/tm902089733300000/a903202310/lys/models/Meta-Llama-3.1-8B-Instruct"
)
OUT = REPO / "experiments/attention_mechanism_audit/outputs/Meta-Llama-3.1-8B-Instruct"
INPUTS = [OUT / "routing_state/train", OUT / "routing_state/test"]

SAMPLE_ID = "11907"
IMAGE = OUT / "sample_views" / f"{SAMPLE_ID}.png"

# %%
from IPython.display import Image, display

plot_saved_sample(inputs=INPUTS, sample_id=SAMPLE_ID, model_path=MODEL, output=IMAGE)
display(Image(filename=str(IMAGE)))
